# %%
import sqlite3
import pandas as pd

# %%
covid2 = pd.read_json('corona-out-2',lines = True)

# %%
covid2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18518 entries, 0 to 18517
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 18518 non-null  datetime64[ns, UTC]
#  1   id                         18518 non-null  int64
#  2   id_str                     18518 non-null  int64
#  3   text                       18518 non-null  object
#  4   source                     18518 non-null  object
#  5   truncated                  18518 non-null  bool
#  6   in_reply_to_status_id      2528 non-null   float64
#  7   in_reply_to_status_id_str  2528 non-null   float64
#  8   in_reply_to_user_id        2734 non-null   float64
#  9   in_reply_to_user_id_str    2734 non-null   float64
#  10  in_reply_to_screen_name    2734 non-null   object
#  11  user                       18518 non-null  object
#  12  geo                        13 non-null     object
#  13  coordinates                13 non-null     object
#  14  place                      273 non-null    object
#  15  contributors               0 non-null      float64
#  16  retweeted_status           11159 non-null  object
#  17  quoted_status_id           3013 non-null   float64
#  18  quoted_status_id_str       3013 non-null   float64
#  19  quoted_status              2994 non-null   object
#  20  quoted_status_permalink    2994 non-null   object
#  21  is_quote_status            18518 non-null  bool
#  22  quote_count                18518 non-null  int64
#  23  reply_count                18518 non-null  int64
#  24  retweet_count              18518 non-null  int64
#  25  favorite_count             18518 non-null  int64
#  26  entities                   18518 non-null  object
#  27  favorited                  18518 non-null  bool
#  28  retweeted                  18518 non-null  bool
#  29  filter_level               18518 non-null  object
#  30  lang                       18518 non-null  object
#  31  timestamp_ms               18518 non-null  datetime64[ns]
#  32  display_text_range         3183 non-null   object
#  33  extended_tweet             2912 non-null   object
#  34  possibly_sensitive         3449 non-null   float64
#  35  extended_entities          1084 non-null   object
#  36  withheld_in_countries      81 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), datetime64[ns](1), float64(8), int64(6), object(17)
# memory usage: 4.7+ MB

# %%
covid2['user'][1]
# Out:
# {'id': 1225145123920588805,
#  'id_str': '1225145123920588805',
#  'name': 'efe09',
#  'screen_name': 'efe0927183508',
#  'location': None,
#  'url': None,
#  'description': "Allah'ın en değerli eseri insandır.\nCanı yanan sabretsin.\nCan yakan, canının yanacağı günü beklesin..\n677 khk\nRT düşüncem olduğu anlamına gelmez bilgi amaçlıdır",
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 653,
#  'friends_count': 983,
#  'listed_count': 0,
#  'favourites_count': 1255,
#  'statuses_count': 4177,
#  'created_at': 'Wed Feb 05 19:52:38 +0000 2020',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1225145123920588805/1585222614',
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
df = pd.json_normalize(covid2['user'])

# %%
df
# Out:
#                         id               id_str                  name  \
# 0      1242817830946508801  1242817830946508801              juwelz v
# 1      1225145123920588805  1225145123920588805                 efe09
# 2                101007632            101007632           Ravin Gupta
# 3      1230170166614482944  1230170166614482944            Carpe diem
# 4               4707764075           4707764075    UpsidedownTurtle 🧢
# ...                    ...                  ...                   ...
# 18513            491861073            491861073  KATHRYN NICHOLSON 🇨🇦
# 18514   947922936631103489   947922936631103489          CEO of Horny
# 18515   884226045846704129   884226045846704129              sophia ♡
# 18516            631821317            631821317          Jude Dockray
# 18517           2283278160           2283278160               Mr rius
#
#            screen_name                        location  \
# 0             juwelz_v      Lower East Side, Manhattan
# 1        efe0927183508                            None
# 2            IamRaavin                           india
# 3      Carpedi92670638                            None
# 4              Adakisn                            None
# ...                ...                             ...
# 18513  bucksbratbonnie                            None
# 18514      pimpjuice_k                            None
# 18515    ssophhiiiaaaa                   angelo state
# 18516      JudeDockray  Liverpool, Winchester, Toronto
# 18517      AwhexWibowo           Yogyakarta, Indonesia
#
#                              url  \
# 0      https://linktr.ee/juwelzv
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# ...                          ...
# 18513                       None
# 18514                       None
# 18515                       None
# 18516                       None
# 18517                       None
#
#                                              description translator_type  \
# 0      Event Lyfe LLC .. Brand Ambassador: #visionary...            none
# 1      Allah'ın en değerli eseri insandır.\nCanı yana...            none
# 2      Tweet is personal opinion and Retweet is not e...            none
# 3                Yezidin hârcı zulüm\nYiğidin burcu ölüm            none
# 4                                                   None            none
# ...                                                  ...             ...
# 18513                                               None            none
# 18514  Nobel peace prize winner, Mulit-Platinum produ...            none
# 18515              im shy and also kinda funny sometimes            none
# 18516  Wessex Urology, fellowship trained Andrology a...            none
# 18517                                    have fun go mad            none
#
#        protected  verified  ...  profile_text_color  \
# 0          False     False  ...              333333
# 1          False     False  ...              333333
# 2          False     False  ...              3C3940
# 3          False     False  ...              333333
# 4          False     False  ...              333333
# ...          ...       ...  ...                 ...
# 18513      False     False  ...              333333
# 18514      False     False  ...              333333
# 18515      False     False  ...              000000
# 18516      False     False  ...              333333
# 18517      False     False  ...              333333
#
#        profile_use_background_image  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
# ...                             ...
# 18513                          True
# 18514                          True
# 18515                         False
# 18516                          True
# 18517                          True
#
#                                        profile_image_url  \
# 0      http://pbs.twimg.com/profile_images/1246253579...
# 1      http://pbs.twimg.com/profile_images/1243137514...
# 2      http://pbs.twimg.com/profile_images/1208036848...
# 3      http://pbs.twimg.com/profile_images/1245348061...
# 4      http://abs.twimg.com/sticky/default_profile_im...
# ...                                                  ...
# 18513  http://pbs.twimg.com/profile_images/1826014751...
# 18514  http://pbs.twimg.com/profile_images/1210358453...
# 18515  http://pbs.twimg.com/profile_images/1248515875...
# 18516  http://pbs.twimg.com/profile_images/8569512789...
# 18517  http://pbs.twimg.com/profile_images/1045333930...
#
#                                  profile_image_url_https  \
# 0      https://pbs.twimg.com/profile_images/124625357...
# 1      https://pbs.twimg.com/profile_images/124313751...
# 2      https://pbs.twimg.com/profile_images/120803684...
# 3      https://pbs.twimg.com/profile_images/124534806...
# 4      https://abs.twimg.com/sticky/default_profile_i...
# ...                                                  ...
# 18513  https://pbs.twimg.com/profile_images/182601475...
# 18514  https://pbs.twimg.com/profile_images/121035845...
# 18515  https://pbs.twimg.com/profile_images/124851587...
# 18516  https://pbs.twimg.com/profile_images/856951278...
# 18517  https://pbs.twimg.com/profile_images/104533393...
#
#                                       profile_banner_url default_profile  \
# 0      https://pbs.twimg.com/profile_banners/12428178...            True
# 1      https://pbs.twimg.com/profile_banners/12251451...            True
# 2                                                    NaN           False
# 3      https://pbs.twimg.com/profile_banners/12301701...            True
# 4                                                    NaN            True
# ...                                                  ...             ...
# 18513                                                NaN            True
# 18514  https://pbs.twimg.com/profile_banners/94792293...            True
# 18515  https://pbs.twimg.com/profile_banners/88422604...           False
# 18516  https://pbs.twimg.com/profile_banners/63182131...            True
# 18517  https://pbs.twimg.com/profile_banners/22832781...            True
#
#       default_profile_image following  follow_request_sent notifications
# 0                     False      None                 None          None
# 1                     False      None                 None          None
# 2                     False      None                 None          None
# 3                     False      None                 None          None
# 4                     False      None                 None          None
# ...                     ...       ...                  ...           ...
# 18513                 False      None                 None          None
# 18514                 False      None                 None          None
# 18515                 False      None                 None          None
# 18516                 False      None                 None          None
# 18517                 False      None                 None          None
#
# [18518 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18518 entries, 0 to 18517
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  18518 non-null  int64
#  1   id_str                              18518 non-null  object
#  2   name                                18518 non-null  object
#  3   screen_name                         18518 non-null  object
#  4   location                            11456 non-null  object
#  5   url                                 3974 non-null   object
#  6   description                         14608 non-null  object
#  7   translator_type                     18518 non-null  object
#  8   protected                           18518 non-null  bool
#  9   verified                            18518 non-null  bool
#  10  followers_count                     18518 non-null  int64
#  11  friends_count                       18518 non-null  int64
#  12  listed_count                        18518 non-null  int64
#  13  favourites_count                    18518 non-null  int64
#  14  statuses_count                      18518 non-null  int64
#  15  created_at                          18518 non-null  object
#  16  utc_offset                          0 non-null      object
#  17  time_zone                           0 non-null      object
#  18  geo_enabled                         18518 non-null  bool
#  19  lang                                0 non-null      object
#  20  contributors_enabled                18518 non-null  bool
#  21  is_translator                       18518 non-null  bool
#  22  profile_background_color            18518 non-null  object
#  23  profile_background_image_url        18518 non-null  object
#  24  profile_background_image_url_https  18518 non-null  object
#  25  profile_background_tile             18518 non-null  bool
#  26  profile_link_color                  18518 non-null  object
#  27  profile_sidebar_border_color        18518 non-null  object
#  28  profile_sidebar_fill_color          18518 non-null  object
#  29  profile_text_color                  18518 non-null  object
#  30  profile_use_background_image        18518 non-null  bool
#  31  profile_image_url                   18518 non-null  object
#  32  profile_image_url_https             18518 non-null  object
#  33  profile_banner_url                  14012 non-null  object
#  34  default_profile                     18518 non-null  bool
#  35  default_profile_image               18518 non-null  bool
#  36  following                           0 non-null      object
#  37  follow_request_sent                 0 non-null      object
#  38  notifications                       0 non-null      object
# dtypes: bool(9), int64(6), object(24)
# memory usage: 4.4+ MB

# %%
df = df.drop(['utc_offset', 'time_zone','lang', 'following', 'follow_request_sent', 'notifications'], axis=1)

# %%
# Connect to the SQLite database
conn = sqlite3.connect('database.db')

# %% [markdown]
# # Dropped variables
# utc_offset
# time_zone
# lang
# following
# follow_request_sent
# notifications

# %%
# Define the SQL query to create the table
# CHECK CREATED AT FOR TYPE (DATE TIME FIELD)
sql = """
CREATE TABLE user (
    id BIGINT,
    id_str TEXT,
    name TEXT,
    screen_name TEXT,
    location TEXT,
    url TEXT,
    description TEXT,
    translator_type TEXT,
    protected BOOLEAN,
    verified BOOLEAN,
    followers_count BIGINT,
    friends_count BIGINT,
    listed_count BIGINT,
    favourites_count BIGINT,
    statuses_count BIGINT,
    created_at TEXT,
    geo_enabled BOOLEAN,
    contributors_enabled BOOLEAN,
    is_translator BOOLEAN,
    profile_background_color TEXT,
    profile_background_image_url TEXT,
    profile_background_image_url_https TEXT,
    profile_background_tile BOOLEAN,
    profile_link_color TEXT,
    profile_sidebar_border_color TEXT,
    profile_sidebar_fill_color TEXT,
    profile_text_color TEXT,
    profile_use_background_image BOOLEAN,
    profile_image_url TEXT,
    profile_image_url_https TEXT,
    profile_banner_url TEXT,
    default_profile BOOLEAN,
    default_profile_image BOOLEAN
);
"""

# Execute the SQL query to create the table
conn.execute(sql)

# Commit the changes and close the connection
conn.commit()

# %%
for i, row in df.iterrows():
    # Define the SQL query to insert the row into the table
    sql = """
    INSERT INTO user (id, id_str, name, screen_name, location, url, description, translator_type,
                       protected, verified, followers_count, friends_count, listed_count, favourites_count,
                       statuses_count, created_at, geo_enabled, contributors_enabled, is_translator,
                       profile_background_color, profile_background_image_url, profile_background_image_url_https,
                       profile_background_tile, profile_link_color, profile_sidebar_border_color,
                       profile_sidebar_fill_color, profile_text_color, profile_use_background_image,
                       profile_image_url, profile_image_url_https, profile_banner_url, default_profile,
                       default_profile_image)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);
    """
    conn.execute(sql, tuple(row))
    conn.commit()

# %% [markdown]
# # Querying

# %%
username = input("Enter the username: ")
# Out:
# Enter the username: efe09

# %%
sql = f"""
    SELECT * FROM user WHERE name='{username}'
"""
result = conn.execute(sql)
# print the results
for row in result:
    print(row)
# Out:
# (1225145123920588805, '1225145123920588805', 'efe09', 'efe0927183508', None, None, "Allah'ın en değerli eseri insandır.\nCanı yanan sabretsin.\nCan yakan, canının yanacağı günü beklesin..\n677 khk\nRT düşüncem olduğu anlamına gelmez bilgi amaçlıdır", 'none', 0, 0, 653, 983, 0, 1255, 4177, 'Wed Feb 05 19:52:38 +0000 2020', 0, 0, 0, 'F5F8FA', '', '', 0, '1DA1F2', 'C0DEED', 'DDEEF6', '333333', 1, 'http://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_banners/1225145123920588805/1585222614', 1, 0)
# (1225145123920588805, '1225145123920588805', 'efe09', 'efe0927183508', None, None, "Allah'ın en değerli eseri insandır.\nCanı yanan sabretsin.\nCan yakan, canının yanacağı günü beklesin..\n677 khk\nRT düşüncem olduğu anlamına gelmez bilgi amaçlıdır", 'none', 0, 0, 653, 983, 0, 1255, 4179, 'Wed Feb 05 19:52:38 +0000 2020', 0, 0, 0, 'F5F8FA', '', '', 0, '1DA1F2', 'C0DEED', 'DDEEF6', '333333', 1, 'http://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_banners/1225145123920588805/1585222614', 1, 0)
# (1225145123920588805, '1225145123920588805', 'efe09', 'efe0927183508', None, None, "Allah'ın en değerli eseri insandır.\nCanı yanan sabretsin.\nCan yakan, canının yanacağı günü beklesin..\n677 khk\nRT düşüncem olduğu anlamına gelmez bilgi amaçlıdır", 'none', 0, 0, 654, 983, 0, 1256, 4199, 'Wed Feb 05 19:52:38 +0000 2020', 0, 0, 0, 'F5F8FA', '', '', 0, '1DA1F2', 'C0DEED', 'DDEEF6', '333333', 1, 'http://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_banners/1225145123920588805/1585222614', 1, 0)
# (1225145123920588805, '1225145123920588805', 'efe09', 'efe0927183508', None, None, "Allah'ın en değerli eseri insandır.\nCanı yanan sabretsin.\nCan yakan, canının yanacağı günü beklesin..\n677 khk\nRT düşüncem olduğu anlamına gelmez bilgi amaçlıdır", 'none', 0, 0, 654, 983, 0, 1256, 4200, 'Wed Feb 05 19:52:38 +0000 2020', 0, 0, 0, 'F5F8FA', '', '', 0, '1DA1F2', 'C0DEED', 'DDEEF6', '333333', 1, 'http://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_images/1243137514665361409/95Mv0oRS_normal.jpg', 'https://pbs.twimg.com/profile_banners/1225145123920588805/1585222614', 1, 0)

# %% [raw]
# #only read queries, write can be done without this
#
# import sqlite3
#
# class UserDatabase:
#     def __init__(self, db_path):
#         # initialize the database connection
#         self.conn = sqlite3.connect(db_path)
#
#     def __del__(self):
#         # close the database connection when the object is destroyed
#         self.conn.close()
#
#     def search_by_username(self, username):
#         # define the SQL query
#         sql = f"""
#             SELECT id, name, screen_name FROM user WHERE name='{username}'
#         """
#
#         # execute the SQL query and get the results
#         result = self.conn.execute(sql)
#
#         # return the results as a list of dictionaries
#         return [dict(row) for row in result]
